# %%
! pip install wheel

# Install the UIC repo
! pip install ucimlrepo

from sklearn.metrics import classification_report
from gplearn.genetic import SymbolicClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedShuffleSplit, cross_validate
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
import pandas as pd 
import math
from statistics import mean 
from statistics import stdev
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import accuracy_score
import warnings

# Ignore all warnings
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: wheel in c:\users\keamodladla\anaconda3\lib\site-packages (0.43.0)
# Requirement already satisfied: ucimlrepo in c:\users\keamodladla\anaconda3\lib\site-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\keamodladla\anaconda3\lib\site-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in c:\users\keamodladla\anaconda3\lib\site-packages (from ucimlrepo) (2024.6.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\keamodladla\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\keamodladla\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\keamodladla\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\keamodladla\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\keamodladla\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.16.0)

# %%
# Import the databases
from ucimlrepo import fetch_ucirepo 
  
# fetch datasets
iris = fetch_ucirepo(id=53) 
wine_quality = fetch_ucirepo(id=186) 
rice_cammeo_and_osmancik = fetch_ucirepo(id=545) 
breast_cancer_wisconsin_original = fetch_ucirepo(id=15) 
magic_gamma_telescope = fetch_ucirepo(id=159) 
banknote_authentication = fetch_ucirepo(id=267)
yeast = fetch_ucirepo(id=110)
letter_recognition = fetch_ucirepo(id=59) 

datasets = [iris, wine_quality,rice_cammeo_and_osmancik,breast_cancer_wisconsin_original,
            magic_gamma_telescope, banknote_authentication, yeast, letter_recognition]

datasets_strings = ['iris', 'wine_quality','rice_cammeo_and_osmancik','breast_cancer_wisconsin_original',
            'magic_gamma_telescope', 'banknote_authentication', 'yeast', 'letter_recognition']

# %%
# Configure the classifiers

#----------------------------------------------------------------------------------------------
# CART
from sklearn.tree import DecisionTreeClassifier

#----------------------------------------------------------------------------------------------
# C4.5
from ohmt.trees.univariate.c4 import C45
from ohmt.trees.splits.evaluation import gini

#----------------------------------------------------------------------------------------------
# OC1
from ohmt.trees.multivariate.oc1 import OC1
from ohmt.trees.splits.evaluation import gini

#----------------------------------------------------------------------------------------------
# SVM_ODT
! pip install Stree
from stree import Stree
# Out:
# Requirement already satisfied: Stree in c:\users\keamodladla\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: mufs in c:\users\keamodladla\anaconda3\lib\site-packages (from Stree) (0.1.3)
# Requirement already satisfied: scikit-learn>1.0 in c:\users\keamodladla\anaconda3\lib\site-packages (from Stree) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\keamodladla\anaconda3\lib\site-packages (from scikit-learn>1.0->Stree) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\keamodladla\anaconda3\lib\site-packages (from scikit-learn>1.0->Stree) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\keamodladla\anaconda3\lib\site-packages (from scikit-learn>1.0->Stree) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\keamodladla\anaconda3\lib\site-packages (from scikit-learn>1.0->Stree) (2.2.0)

# %% [markdown]
# # Experiment 1: Proposed method against Standard Decision Tree Algorithms

# %%
#----------------------------------------------------------------------------------------------
# CART

# Create an empty dataframe 
col_names =  ['database', 'mean_score', 'mean_std'] 
cart_df  = pd.DataFrame(columns = col_names) 
cart_df['database'] = datasets_strings

# Iterate over datasets
acc_scores = []
std_scores = []
for ds_cnt, ds in enumerate(datasets):
    # Preprocess dataset, and split into training and test sets
    # data as pandas dataframes 
    X = ds.data.features 
    y = ds.data.targets 

    # Drop empty entries, if any
    empty_row_idx = [index for index, row in X.iterrows() if row.isnull().any()]
    if len(empty_row_idx) >= 1:
        X = X.drop(index=empty_row_idx)
        y = y.drop(index=empty_row_idx)
        
    X = StandardScaler().fit_transform(X)

    sss = StratifiedShuffleSplit(n_splits=10, test_size=0.3)    
    dtc = DecisionTreeClassifier()

    acc_each_run = []
    std_each_run = []
    
    for train_index, test_index in sss.split(X, y):
            X_train, X_test = X[train_index], X[test_index]
            y_train, y_test = y.iloc[train_index], y.iloc[test_index]

            model = dtc.fit(X_train, y_train)
            score = cross_val_score(model, X_test, y_test, cv=10)
            acc_each_run.append(score.mean().round(3))
            std_each_run.append(score.std().round(3))

    ave_score = mean(acc_each_run)
    ave_std = mean(std_each_run)

    acc_scores.append(ave_score)
    std_scores.append(ave_std)

cart_df[ 'mean_score'] = acc_scores
cart_df[ 'mean_std'] = std_scores
cart_df.set_index("database", inplace = True)

# %%
#----------------------------------------------------------------------------------------------
# C4.5

# Create an empty dataframe 
col_names =  ['database', 'mean_score', 'mean_std'] 
c45_df  = pd.DataFrame(columns = col_names) 
c45_df['database'] = datasets_strings

# Iterate over datasets
acc_scores = []
std_scores = []
for ds_cnt, ds in enumerate(datasets):
    # Preprocess dataset, and split into training and test sets
    # data as pandas dataframes 
    X = ds.data.features 
    y = ds.data.targets 

    # Drop empty entries, if any
    empty_row_idx = [index for index, row in X.iterrows() if row.isnull().any()]
    if len(empty_row_idx) >= 1:
        X = X.drop(index=empty_row_idx)
        y = y.drop(index=empty_row_idx)
        
    ordinal_encoder = OrdinalEncoder()
    X = X.values[:, :-1]
    y = ordinal_encoder.fit_transform(y)
    y =  y[:, -1].astype(int)

    # Generate the 10 runs to calculate the accuracy and standard deviation
    acc_each_run = []
    i = 1
    while i < 11:
        # Test and train sets
        train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=.3,
                                                               stratify=y)
        c45_tree = C45()
        c45_tree = c45_tree.fit(train_features, train_labels, max_depth=10, min_eps=0.000000000000001, min_samples=10,
                    node_fitness_function=gini)
    
        # Evaluate tree 
        predicted_test_labels = c45_tree.predict(test_features) 
        score = accuracy_score(test_labels, predicted_test_labels)
    
        acc_each_run.append(score)
        i += 1
    

    ave_score = mean(acc_each_run)
    ave_std = stdev(std_each_run)

    acc_scores.append(round(ave_score,3))
    std_scores.append(round(ave_std,3))

c45_df[ 'mean_score'] = acc_scores
c45_df[ 'mean_std'] = std_scores
c45_df.set_index("database", inplace = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 31
#      28 train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=.3,
#      29                                                        stratify=y)
#      30 c45_tree = C45()
# ---> 31 c45_tree = c45_tree.fit(train_features, train_labels, max_depth=10, min_eps=0.000000000000001, min_samples=10,
#      32             node_fitness_function=gini)
#      34 # Evaluate tree
#      35 predicted_test_labels = c45_tree.predict(test_features)
#
# File ~\OneDrive - MONOCLE SOLUTIONS (PTY) LTD\Documents\Oblique_Decision_Tree_Induction_using_GP\ohmt\trees\structure\trees.py:376, in Tree.fit(self, data, labels, max_depth, min_eps, min_samples, node_fitness_function, node_hyperparameters, **step_hyperparameters)
#     373 right_child_labels = labels[~left_child_indices]
#     375 logging.debug("Fitting left child...")
# --> 376 self.__rec_fit(parent_node=root,
#     377                data=left_child_data, labels=left_child_labels, classes=classes,
#     378                node_fitness_function=node_fitness_function,
#     379                direction="left",
#     380                depth=1, max_depth=max_depth, min_eps=min_eps, min_samples=min_samples,
#     381                node_hyperparameters={} if node_hyperparameters is None else node_hyperparameters,
#     382                **step_hyperparameters)
#     383 logging.debug("Fitting right child...")
#     384 self.__rec_fit(parent_node=root,
#     385                data=right_child_data, labels=right_child_labels, classes=classes,
#     386                node_fitness_function=node_fitness_function,
#    (...)
#     389                node_hyperparameters={} if node_hyperparameters is None else node_hyperparameters,
#     390                **step_hyperparameters)
#
# File ~\OneDrive - MONOCLE SOLUTIONS (PTY) LTD\Documents\Oblique_Decision_Tree_Induction_using_GP\ohmt\trees\structure\trees.py:453, in Tree.__rec_fit(self, parent_node, data, labels, classes, direction, depth, max_depth, min_eps, min_samples, node_fitness_function, node_hyperparameters, **step_hyperparameters)
#     450 right_child_data, right_child_labels = data[~data_indices], labels[~data_indices]
#     452 logging.debug(f"Fitting child on {left_child_data.shape[0]} nodes...")
# --> 453 self.__rec_fit(parent_node=fit_node,
#     454                data=left_child_data, labels=left_child_labels, classes=classes,
#     455                direction="left",
#     456                depth=depth + 1, max_depth=max_depth, min_eps=min_eps, min_samples=min_samples,
#     457                node_fitness_function=node_fitness_function,
#     458                node_hyperparameters=node_hyperparameters,
#     459                step_hyperparameters=step_hyperparameters)
#     460 logging.debug(f"Fitting child on {right_child_data.shape[0]} nodes...")
#     461 self.__rec_fit(parent_node=fit_node,
#     462                data=right_child_data, labels=right_child_labels, classes=classes,
#     463                direction="right",
#    (...)
#     466                node_hyperparameters=node_hyperparameters,
#     467                step_hyperparameters=step_hyperparameters)
#
# File ~\OneDrive - MONOCLE SOLUTIONS (PTY) LTD\Documents\Oblique_Decision_Tree_Induction_using_GP\ohmt\trees\structure\trees.py:453, in Tree.__rec_fit(self, parent_node, data, labels, classes, direction, depth, max_depth, min_eps, min_samples, node_fitness_function, node_hyperparameters, **step_hyperparameters)
#     450 right_child_data, right_child_labels = data[~data_indices], labels[~data_indices]
#     452 logging.debug(f"Fitting child on {left_child_data.shape[0]} nodes...")
# --> 453 self.__rec_fit(parent_node=fit_node,
#     454                data=left_child_data, labels=left_child_labels, classes=classes,
#     455                direction="left",
#     456                depth=depth + 1, max_depth=max_depth, min_eps=min_eps, min_samples=min_samples,
#     457                node_fitness_function=node_fitness_function,
#     458                node_hyperparameters=node_hyperparameters,
#     459                step_hyperparameters=step_hyperparameters)
#     460 logging.debug(f"Fitting child on {right_child_data.shape[0]} nodes...")
#     461 self.__rec_fit(parent_node=fit_node,
#     462                data=right_child_data, labels=right_child_labels, classes=classes,
#     463                direction="right",
#    (...)
#     466                node_hyperparameters=node_hyperparameters,
#     467                step_hyperparameters=step_hyperparameters)
#
# File ~\OneDrive - MONOCLE SOLUTIONS (PTY) LTD\Documents\Oblique_Decision_Tree_Induction_using_GP\ohmt\trees\structure\trees.py:453, in Tree.__rec_fit(self, parent_node, data, labels, classes, direction, depth, max_depth, min_eps, min_samples, node_fitness_function, node_hyperparameters, **step_hyperparameters)
#     450 right_child_data, right_child_labels = data[~data_indices], labels[~data_indices]
#     452 logging.debug(f"Fitting child on {left_child_data.shape[0]} nodes...")
# --> 453 self.__rec_fit(parent_node=fit_node,
#     454                data=left_child_data, labels=left_child_labels, classes=classes,
#     455                direction="left",
#     456                depth=depth + 1, max_depth=max_depth, min_eps=min_eps, min_samples=min_samples,
#     457                node_fitness_function=node_fitness_function,
#     458                node_hyperparameters=node_hyperparameters,
#     459                step_hyperparameters=step_hyperparameters)
#     460 logging.debug(f"Fitting child on {right_child_data.shape[0]} nodes...")
#     461 self.__rec_fit(parent_node=fit_node,
#     462                data=right_child_data, labels=right_child_labels, classes=classes,
#     463                direction="right",
#    (...)
#     466                node_hyperparameters=node_hyperparameters,
#     467                step_hyperparameters=step_hyperparameters)
#
# File ~\OneDrive - MONOCLE SOLUTIONS (PTY) LTD\Documents\Oblique_Decision_Tree_Induction_using_GP\ohmt\trees\structure\trees.py:461, in Tree.__rec_fit(self, parent_node, data, labels, classes, direction, depth, max_depth, min_eps, min_samples, node_fitness_function, node_hyperparameters, **step_hyperparameters)
#     453 self.__rec_fit(parent_node=fit_node,
#     454                data=left_child_data, labels=left_child_labels, classes=classes,
#     455                direction="left",
#    (...)
#     458                node_hyperparameters=node_hyperparameters,
#     459                step_hyperparameters=step_hyperparameters)
#     460 logging.debug(f"Fitting child on {right_child_data.shape[0]} nodes...")
# --> 461 self.__rec_fit(parent_node=fit_node,
#     462                data=right_child_data, labels=right_child_labels, classes=classes,
#     463                direction="right",
#     464                depth=depth + 1, max_depth=max_depth, min_eps=min_eps, min_samples=min_samples,
#     465                node_fitness_function=node_fitness_function,
#     466                node_hyperparameters=node_hyperparameters,
#     467                step_hyperparameters=step_hyperparameters)
#
# File ~\OneDrive - MONOCLE SOLUTIONS (PTY) LTD\Documents\Oblique_Decision_Tree_Induction_using_GP\ohmt\trees\structure\trees.py:453, in Tree.__rec_fit(self, parent_node, data, labels, classes, direction, depth, max_depth, min_eps, min_samples, node_fitness_function, node_hyperparameters, **step_hyperparameters)
#     450 right_child_data, right_child_labels = data[~data_indices], labels[~data_indices]
#     452 logging.debug(f"Fitting child on {left_child_data.shape[0]} nodes...")
# --> 453 self.__rec_fit(parent_node=fit_node,
#     454                data=left_child_data, labels=left_child_labels, classes=classes,
#     455                direction="left",
#     456                depth=depth + 1, max_depth=max_depth, min_eps=min_eps, min_samples=min_samples,
#     457                node_fitness_function=node_fitness_function,
#     458                node_hyperparameters=node_hyperparameters,
#     459                step_hyperparameters=step_hyperparameters)
#     460 logging.debug(f"Fitting child on {right_child_data.shape[0]} nodes...")
#     461 self.__rec_fit(parent_node=fit_node,
#     462                data=right_child_data, labels=right_child_labels, classes=classes,
#     463                direction="right",
#    (...)
#     466                node_hyperparameters=node_hyperparameters,
#     467                step_hyperparameters=step_hyperparameters)
#
# File ~\OneDrive - MONOCLE SOLUTIONS (PTY) LTD\Documents\Oblique_Decision_Tree_Induction_using_GP\ohmt\trees\structure\trees.py:453, in Tree.__rec_fit(self, parent_node, data, labels, classes, direction, depth, max_depth, min_eps, min_samples, node_fitness_function, node_hyperparameters, **step_hyperparameters)
#     450 right_child_data, right_child_labels = data[~data_indices], labels[~data_indices]
#     452 logging.debug(f"Fitting child on {left_child_data.shape[0]} nodes...")
# --> 453 self.__rec_fit(parent_node=fit_node,
#     454                data=left_child_data, labels=left_child_labels, classes=classes,
#     455                direction="left",
#     456                depth=depth + 1, max_depth=max_depth, min_eps=min_eps, min_samples=min_samples,
#     457                node_fitness_function=node_fitness_function,
#     458                node_hyperparameters=node_hyperparameters,
#     459                step_hyperparameters=step_hyperparameters)
#     460 logging.debug(f"Fitting child on {right_child_data.shape[0]} nodes...")
#     461 self.__rec_fit(parent_node=fit_node,
#     462                data=right_child_data, labels=right_child_labels, classes=classes,
#     463                direction="right",
#    (...)
#     466                node_hyperparameters=node_hyperparameters,
#     467                step_hyperparameters=step_hyperparameters)
#
#     [... skipping similar frames: Tree.__rec_fit at line 453 (1 times)]
#
# File ~\OneDrive - MONOCLE SOLUTIONS (PTY) LTD\Documents\Oblique_Decision_Tree_Induction_using_GP\ohmt\trees\structure\trees.py:453, in Tree.__rec_fit(self, parent_node, data, labels, classes, direction, depth, max_depth, min_eps, min_samples, node_fitness_function, node_hyperparameters, **step_hyperparameters)
#     450 right_child_data, right_child_labels = data[~data_indices], labels[~data_indices]
#     452 logging.debug(f"Fitting child on {left_child_data.shape[0]} nodes...")
# --> 453 self.__rec_fit(parent_node=fit_node,
#     454                data=left_child_data, labels=left_child_labels, classes=classes,
#     455                direction="left",
#     456                depth=depth + 1, max_depth=max_depth, min_eps=min_eps, min_samples=min_samples,
#     457                node_fitness_function=node_fitness_function,
#     458                node_hyperparameters=node_hyperparameters,
#     459                step_hyperparameters=step_hyperparameters)
#     460 logging.debug(f"Fitting child on {right_child_data.shape[0]} nodes...")
#     461 self.__rec_fit(parent_node=fit_node,
#     462                data=right_child_data, labels=right_child_labels, classes=classes,
#     463                direction="right",
#    (...)
#     466                node_hyperparameters=node_hyperparameters,
#     467                step_hyperparameters=step_hyperparameters)
#
# File ~\OneDrive - MONOCLE SOLUTIONS (PTY) LTD\Documents\Oblique_Decision_Tree_Induction_using_GP\ohmt\trees\structure\trees.py:425, in Tree.__rec_fit(self, parent_node, data, labels, classes, direction, depth, max_depth, min_eps, min_samples, node_fitness_function, node_hyperparameters, **step_hyperparameters)
#     422     return
#     424 # stopping criteria
# --> 425 should_stop_for_depth = self.should_stop_for_max_depth(depth, max_depth, parent_node, labels, validation_data=data)
#     426 should_stop_for_min_samples = self.should_stop_for_min_samples(data, labels, direction, parent_node, min_samples)
#     427 should_stop_for_one_class = self.should_stop_for_one_class(labels, parent_node, direction, validation_data=data)
#
# File ~\OneDrive - MONOCLE SOLUTIONS (PTY) LTD\Documents\Oblique_Decision_Tree_Induction_using_GP\ohmt\trees\structure\trees.py:252, in Tree.should_stop_for_max_depth(self, depth, max_depth, parent_node, validation_labels, validation_data)
#     250 if depth >= max_depth - 1:
#     251     logging.debug(f"Reached max depth of {max_depth}")
# --> 252     children = [self.build_leaf(validation_labels, data=validation_data), self.build_leaf(1 - validation_labels, data=validation_data)]
#     253     parent_node.children = children
#     255     return True
#
# File ~\OneDrive - MONOCLE SOLUTIONS (PTY) LTD\Documents\Oblique_Decision_Tree_Induction_using_GP\ohmt\trees\structure\trees.py:681, in Tree.build_leaf(self, labels, data)
#     679 def build_leaf(self, labels: numpy.array, data: Optional[numpy.ndarray] = None) -> Leaf:
#     680     """Build a Leaf for the given labels."""
# --> 681     probabilities = numpy.bincount(labels) / labels.size
#     683     if probabilities.size == 0:
#     684         probabilities = numpy.array([0.5, 0.5])
#
# ValueError: 'list' argument must have no negative elements

# %% [markdown]
# # Experiment 2: Proposed method against Oblique Decision Tree Algorithms

# %%
#----------------------------------------------------------------------------------------------
# OC1

# Create an empty dataframe 
col_names =  ['database', 'mean_score', 'mean_std'] 
oc1_df  = pd.DataFrame(columns = col_names) 
oc1_df['database'] = datasets_strings

# Iterate over datasets
acc_scores = []
std_scores = []
for ds_cnt, ds in enumerate(datasets):
    # Preprocess dataset, and split into training and test sets
    # data as pandas dataframes 
    X = ds.data.features 
    y = ds.data.targets 

    # Drop empty entries, if any
    empty_row_idx = [index for index, row in X.iterrows() if row.isnull().any()]
    if len(empty_row_idx) >= 1:
        X = X.drop(index=empty_row_idx)
        y = y.drop(index=empty_row_idx)
    
    ordinal_encoder = OrdinalEncoder()
    X = X.values[:, :-1]
    y = ordinal_encoder.fit_transform(y)
    y =  y[:, -1].astype(int)

    # Generate the 10 runs to calculate the accuracy and standard deviation
    acc_each_run = []
    i = 1
    while i < 11:
        # Test and train sets
        train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=.3,
                                                               stratify=y)
        oc1_tree = OC1()
        oc1_tree = oc1_tree.fit(train_features, train_labels, max_depth=10, min_eps=0.000000000000001, min_samples=10,
                    node_fitness_function=gini)
    
        # Evaluate tree 
        predicted_test_labels = oc1_tree.predict(test_features) 
        score = accuracy_score(test_labels, predicted_test_labels)
    
        acc_each_run.append(score)
        i += 1

    ave_score = mean(acc_each_run)
    ave_std = stdev(std_each_run)

    acc_scores.append(round(ave_score,3))
    std_scores.append(round(ave_std,3))

oc1_df[ 'mean_score'] = acc_scores
oc1_df[ 'mean_std'] = std_scores
oc1_df.set_index("database", inplace = True)

# %%
#----------------------------------------------------------------------------------------------
#  SVM_ODT

# Create an empty dataframe 
col_names =  ['database', 'mean_score', 'mean_std'] 
svm_tree_df  = pd.DataFrame(columns = col_names) 
svm_tree_df['database'] = datasets_strings

# Iterate over datasets
acc_scores = []
std_scores = []
for ds_cnt, ds in enumerate(datasets):
    # Preprocess dataset, and split into training and test sets
    # data as pandas dataframes 
    X = ds.data.features 
    y = ds.data.targets 

    # Drop empty entries, if any
    empty_row_idx = [index for index, row in X.iterrows() if row.isnull().any()]
    if len(empty_row_idx) >= 1:
        X = X.drop(index=empty_row_idx)
        y = y.drop(index=empty_row_idx)
        
    X = StandardScaler().fit_transform(X)

    
    clf = Stree(random_state=1, max_features="auto")
    val_acc_scores = cross_val_score(clf, X, y,
                         cv=10, n_jobs=-1)

    ave_score = val_acc_scores.mean().round(3)
    ave_std = val_acc_scores.std().round(3)

    acc_scores.append(ave_score)
    std_scores.append(ave_std)

svm_tree_df[ 'mean_score'] = acc_scores
svm_tree_df[ 'mean_std'] = std_scores
svm_tree_df.set_index("database", inplace = True)
